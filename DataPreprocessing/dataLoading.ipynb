# %% [markdown]
# **Kaggle**

# %% [markdown]
# Check Available DataSets

# %%
# Method 1: Command Line
# kaggle datasets list -s "<search string>"

# Method 2: Website
# go to kaggle.com --> search for data set --> in URL copy everything after *data/<search string>

# %% [markdown]
# Download DataSet

# %%
import kagglehub
import pandas as pd

path = kagglehub.dataset_download('mlg-ulb/creditcardfraud')
df_fraud = pd.read_csv(f'{path}/creditcard.csv')
print(df_fraud.head())

# %% [markdown]
# **Seaborn**

# %% [markdown]
# Check Available DataSets

# %%
# Method 1: Website
# go to https://github.com/mwaskom/seaborn-data --> check available .csv list

# Mehod 2: API
import seaborn as sns

datasets = sns.get_dataset_names()
print(datasets)

# %% [markdown]
# Download DataSet

# %%
import seaborn as sns

# classificaion
df_titanic = sns.load_dataset('titanic')
print(df_titanic.head())

# regression
df_tips = sns.load_dataset('tips')
print(df_tips.head())

# %% [markdown]
# **Sklearn**

# %% [markdown]
# Download DataSet

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

housing = fetch_california_housing(as_frame=True)
df_housing = housing.frame
print(df_housing.head())

# %% [markdown]
# **UCI**

# %% [markdown]
# Check Availble DataSets

# %%
# Method 1: Website
# go to https://archive.ics.uci.edu --> serach data set --> in URL there is number(id)

# Method 2: API
from ucimlrepo import list_available_datasets

list_available_datasets()

# %% [markdown]
# Download DataSet

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

abalone = fetch_ucirepo(id=1)
x = abalone.data.features
y = abalone.data.targets

df_abalone = pd.concat([x,y], axis=1)
print(df_abalone.head())
