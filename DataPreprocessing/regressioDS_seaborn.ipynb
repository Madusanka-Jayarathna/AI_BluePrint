# %% [markdown]
# Regression data set from seaborn

# %%
import seaborn as sns

datasets = sns.get_dataset_names()
print(datasets)

# %%
import seaborn as sns

# %%
df_tips = sns.load_dataset('tips')
print(df_tips.head())
