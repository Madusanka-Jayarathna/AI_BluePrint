# %% [markdown]
# Regression data set from sklearn

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
housing = fetch_california_housing(as_frame=True)
df_housing = housing.frame
print(df_housing.head())
