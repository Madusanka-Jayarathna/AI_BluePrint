# %% [markdown]
# Classification data set from Kaggle

# %%
import kagglehub
import pandas as pd

# %%
path = kagglehub.dataset_download('mlg-ulb/creditcardfraud')
df_fraud = pd.read_csv(f'{path}/creditcard.csv')
print(df_fraud.head())
